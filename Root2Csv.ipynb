# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import sys

sys.path.append('../')
from carpet_reconstruction import GetCarpetSignal, num_sort

# %%
path = 'Data/photon_data_noroof/'

filenames = [path + filename for filename in os.listdir(path)]
filenames.sort(key=num_sort)

# %%
h = 10

all_parameters = np.empty((0, 7))
all_signals = np.empty((0, 400))
all_times = np.empty((0, 4))

for filename in filenames:

    print(filename)

    file = uproot.open(filename)
    
    names = np.array(file.keys())
    times = names[:len(names) // 3]
    cover_hists = names[len(names) // 3::2]
    
    cover_signals = np.zeros((len(cover_hists), 400))
    parameters = np.zeros((len(cover_hists), 7))
    
    for i, hist in enumerate(cover_hists):
        
        cov_hist = np.copy(np.flip(file[hist].values().T, 0))
        cover_signals[i] = GetCarpetSignal(cov_hist).flatten()
    
        params = np.array(hist.split(';')[0].split('_')).astype(float)
        params[3] += h*np.tan(np.radians(params[1]))*np.sin(np.radians(params[2]))
        params[4] += h*np.tan(np.radians(params[1]))*np.cos(np.radians(params[2]))
        params[2] = 90 - params[2]
        if params[2] > 180:
            params[2] -= 360
        
        parameters[i] = params

    time_array = np.zeros((len(times), 4))
    
    for i, t in enumerate(times):
        time_array[i] = file[t]['t_ns'].array(library='np')[1:5]

    all_parameters = np.vstack((all_parameters, parameters))
    all_signals = np.vstack((all_signals, cover_signals))
    all_times = np.vstack((all_times, time_array))
# Out:
# Data/photon_data_noroof/output0.root
# Data/photon_data_noroof/output1.root
# Data/photon_data_noroof/output2.root
# Data/photon_data_noroof/output3.root
# Data/photon_data_noroof/output4.root
# Data/photon_data_noroof/output5.root
# Data/photon_data_noroof/output6.root
# Data/photon_data_noroof/output7.root
# Data/photon_data_noroof/output8.root
# Data/photon_data_noroof/output9.root
# Data/photon_data_noroof/output10.root
# Data/photon_data_noroof/output11.root
# Data/photon_data_noroof/output12.root
# Data/photon_data_noroof/output13.root
# Data/photon_data_noroof/output14.root
# Data/photon_data_noroof/output15.root
# Data/photon_data_noroof/output16.root
# Data/photon_data_noroof/output17.root
# Data/photon_data_noroof/output18.root
# Data/photon_data_noroof/output19.root
# Data/photon_data_noroof/output20.root
# Data/photon_data_noroof/output21.root
# Data/photon_data_noroof/output22.root
# Data/photon_data_noroof/output23.root
# Data/photon_data_noroof/output24.root
# Data/photon_data_noroof/output25.root

# %%
all_data = pd.concat([pd.DataFrame(all_parameters, columns=['E, TeV', 'Theta, deg', 'Phi, deg', 'x, m', 'y, m', 'Z_first, cm', 'Ne']), pd.DataFrame(all_times, columns=['remote one trigger time, ns', 'remote two trigger time, ns', 'remote three trigger time, ns', 'remote four trigger time, ns']), pd.DataFrame(all_signals)], axis=1)

# %%
all_data
# Out:
#        E, TeV  Theta, deg  Phi, deg      x, m      y, m  Z_first, cm  \
# 0        10.0    26.29070 -170.7457 -4.875987 -0.794481    5411720.0
# 1        10.0    24.72480  179.5575 -4.604594  0.035562    3056420.0
# 2        10.0    33.06550  165.0478 -6.289910  1.679753    4800420.0
# 3        10.0     2.39251  -44.8180  0.296377 -0.294500    2372820.0
# 4        10.0    30.12960   21.6857  5.392943  2.144554    3009020.0
# ...       ...         ...       ...       ...       ...          ...
# 25995   139.0    21.85680   51.8750  2.476443  3.155488    1989490.0
# 25996   139.0    32.01630 -169.1730 -6.141346 -1.174524    1768770.0
# 25997   139.0    16.35690   72.6233  0.876542  2.801040    2575030.0
# 25998   139.0    25.70070   82.6879  0.612548  4.773686    1723260.0
# 25999   139.0    19.24300   30.3854  3.011300  1.765688    1605900.0
#
#              Ne  remote one trigger time, ns  remote two trigger time, ns  \
# 0        1046.0                     0.000000                     0.000000
# 1        6602.0                     0.000000                106098.257812
# 2         566.0                     0.000000                     0.000000
# 3        5437.0                     0.000000                     0.000000
# 4        2552.0                     0.000000                     0.000000
# ...         ...                          ...                          ...
# 25995  184473.0                 65468.476562                 65411.363281
# 25996  140836.0                 62932.406250                 63089.859375
# 25997  182716.0                 83698.804688                 83640.812500
# 25998  267948.0                 57544.078125                 57513.507812
# 25999  342161.0                 50794.164062                 50762.054688
#
#        remote three trigger time, ns  ...       390       391        392  \
# 0                           0.000000  ...  0.000000  0.000000   0.000000
# 1                      106080.171875  ...  0.000000  0.000000   0.000000
# 2                           0.000000  ...  0.000000  0.000000   0.000000
# 3                           0.000000  ...  0.000000  0.000000   0.000000
# 4                           0.000000  ...  0.000000  0.000000   0.000000
# ...                              ...  ...       ...       ...        ...
# 25995                   65484.886719  ...  2.882883  3.369369   0.731231
# 25996                   62914.738281  ...  5.506006  1.220721   0.711712
# 25997                   83685.968750  ...  4.539039  0.346847   2.903904
# 25998                   57583.761719  ...  2.572072  0.465465   3.954955
# 25999                   50835.687500  ...  5.486486  5.498498  10.854354
#
#              393        394       395       396        397       398       399
# 0       0.000000   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# 1       0.000000   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# 2       0.000000   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# 3       0.000000   0.000000  0.000000  0.000000   0.039039  0.000000  0.000000
# 4       0.000000   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# ...          ...        ...       ...       ...        ...       ...       ...
# 25995   0.692192   0.339339  3.569069  5.051051   3.527027  4.810811  1.611111
# 25996   5.938438   2.876877  2.633634  2.956456   0.882883  2.893393  4.042042
# 25997   5.636637   2.513514  5.417417  2.319820   1.774775  3.672673  2.716216
# 25998   3.247748   7.078078  2.426426  6.993994   0.144144  4.213213  0.722222
# 25999  10.876877  10.969970  9.539039  5.075075  11.965465  3.599099  3.690691
#
# [26000 rows x 411 columns]
